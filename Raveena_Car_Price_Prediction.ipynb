# %% [markdown]
# <a href="https://colab.research.google.com/github/Raveena9597/AI-Disease-Prediction/blob/main/Raveena_Car_Price_Prediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

# Create simple dataset (no download needed 😏)
data = {
    'year': [2010, 2012, 2015, 2018, 2020],
    'km_driven': [50000, 30000, 40000, 20000, 10000],
    'price': [300000, 400000, 500000, 700000, 900000]
}

df = pd.DataFrame(data)

# Features & target
X = df[['year', 'km_driven']]
y = df['price']

# Split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# Model
model = LinearRegression()
model.fit(X_train, y_train)

# Predict
y_pred = model.predict(X_test)

# Output
print("Predicted Prices:", y_pred)
print("MSE:", mean_squared_error(y_test, y_pred))
# Out:
# Predicted Prices: [792176.8707483]
# MSE: 11625827201.629585

# %%
print("Car price prediction model executed successfully")
# Out:
# Car price prediction model executed successfully
